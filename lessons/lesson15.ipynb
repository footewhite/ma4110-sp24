# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Lesson 15: Sampling

# %%
# Run this cell
united = Table.read_table('data/united.csv')
united = united.with_column('Row', np.arange(united.num_rows)).move_to_start('Row')
united

# %% [markdown]
# ## Non-Random (Deterministic) Sampling ##

# %%
# Display all flights that are going to JFK
...

# %%
# Run this cell
# What do you notice?
united.take(np.arange(0, united.num_rows, 1000))

# %%
# Run this cell
# How does it compare to the previous cell?
united.take(make_array(34, 6321, 10040))

# %% [markdown]
# ## Random Sample

# %% [markdown]
# ### Systematic Sample

# %%
# assign to `start` random numbers up to, but not including, 1000
# assign to `systematic_sample` a random 1st row, generated by start, 
# up to the total number of rows in united, and selecting every 1000 rows
# HINT: use .take

start = ...
systematic_sample = ...
systematic_sample.show()

# %% [markdown]
# ### Simple Random Sample

# %%
# Generate a random sample of 20 flights (with replacement)
...

# %%
# Generate a random sample of 20 flights without replacement
...

# %% [markdown]
# ## Distributions ##

# %%
# Run this cell
dice = Table().with_column('Face', np.arange(1, 7))
dice

# %%
# Generate a random sample that displays the result of rolling the 
# die 10 times
...

# %%
roll_bins = np.arange(0.5, 6.6, 1)

# %%
# Create a histogram of randomly selecting the results of rolling the die
# Use the bins provided above
...

# %%
# Create a histogram of randomly selecting 10 results of rolling the die
...

# %%
# Create a histogram of randomly selecting 1000 results of rolling the die
...

# %%
# Create a histogram of randomly selecting 100,000 results of rolling the die
...

# %%
# Create a histogram of randomly selecting 1,000,000 results of rolling the die
...

# %% [markdown]
# ## Large Random Samples ##

# %%
# Run this cell
united

# %%
# Run this cell
united_bins = np.arange(-20, 201, 5)
united.hist('Delay', bins = united_bins)

# %%
# Find the smallest "delay"
min(united.column('Delay'))

# %%
# Find the longest delay
max(united.column('Delay'))

# %%
# Find the average delay
np.average(united.column('Delay'))

# %%
# Create a histogram of the results randomly selecting delay times 
# with a sample size of 10
# use the provided bins of united_bins
...

# %%
# Create a histogram of the results randomly selecting delay times 
# with a sample size of 1000
# use the provided bins of united_bins
...
